# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import fashion_mnist

(x_train, t_train), (x_test, t_test) = fashion_mnist.load_data()

print('\n train shape = ', x_train.shape, 
      ', train label shape = ', t_train.shape)
print(' test shape = ', x_test.shape, 
      ', test label shape =', t_test.shape)

print('\n train label = ', t_train)  # 학습데이터 정답 출력
print(' test label  = ', t_test)     # 테스트 데이터 정답 출력
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
#
#  train shape =  (60000, 28, 28) , train label shape =  (60000,)
#  test shape =  (10000, 28, 28) , test label shape = (10000,)
#
#  train label =  [9 0 0 ... 3 0 5]
#  test label  =  [9 2 1 ... 8 1 5]

# %%
import matplotlib.pyplot as plt

# 25개의 이미지 출력
plt.figure(figsize=(6, 6)) 

for index in range(25):    # 25 개 이미지 출력

    plt.subplot(5, 5, index + 1)  # 5행 5열 
    plt.imshow(x_train[index], cmap='gray') 
    plt.axis('off')   

plt.show()

# %%
plt.imshow(x_train[9], cmap='gray') 
plt.colorbar()   
plt.show()

# %%
plt.title('train label distribution')
plt.grid()
plt.xlabel('label')

plt.hist(t_train, bins=10, rwidth=0.8)

plt.show()

# %%
# 학습데이터 정답 분포 확인

label_distribution = np.zeros(10)

for idx in range(len(t_train)):

    label = int(t_train[idx])

    label_distribution[label] = label_distribution[label] + 1


print(label_distribution)
# Out:
# [6000. 6000. 6000. 6000. 6000. 6000. 6000. 6000. 6000. 6000.]

# %%
# 학습 데이터 / 테스트 데이터 정규화 (Normalization)

x_train = (x_train - 0.0) / (255.0 - 0.0)

x_test = (x_test - 0.0) / (255.0 - 0.0)

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))

model.add(tf.keras.layers.Dense(100, activation='relu'))

model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               78500
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train, t_train, epochs=30, validation_split=0.3)
# Out:
# Epoch 1/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.5474 - accuracy: 0.8096 - val_loss: 0.4409 - val_accuracy: 0.8462
# Epoch 2/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.4037 - accuracy: 0.8554 - val_loss: 0.3783 - val_accuracy: 0.8659
# Epoch 3/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.3607 - accuracy: 0.8705 - val_loss: 0.3722 - val_accuracy: 0.8658
# Epoch 4/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.3367 - accuracy: 0.8769 - val_loss: 0.3636 - val_accuracy: 0.8738
# Epoch 5/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.3157 - accuracy: 0.8852 - val_loss: 0.3398 - val_accuracy: 0.8757
# Epoch 6/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2992 - accuracy: 0.8886 - val_loss: 0.3601 - val_accuracy: 0.8703
# Epoch 7/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2851 - accuracy: 0.8939 - val_loss: 0.3400 - val_accuracy: 0.8811
# Epoch 8/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2753 - accuracy: 0.8980 - val_loss: 0.3329 - val_accuracy: 0.8809
# Epoch 9/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2636 - accuracy: 0.9022 - val_loss: 0.3416 - val_accuracy: 0.8768
# Epoch 10/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2541 - accuracy: 0.9046 - val_loss: 0.3277 - val_accuracy: 0.8807
# Epoch 11/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2460 - accuracy: 0.9090 - val_loss: 0.3354 - val_accuracy: 0.8821
# Epoch 12/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2388 - accuracy: 0.9100 - val_loss: 0.3217 - val_accuracy: 0.8866
# Epoch 13/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2296 - accuracy: 0.9147 - val_loss: 0.3445 - val_accuracy: 0.8803
# Epoch 14/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2238 - accuracy: 0.9169 - val_loss: 0.3287 - val_accuracy: 0.8867
# Epoch 15/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2204 - accuracy: 0.9175 - val_loss: 0.3220 - val_accuracy: 0.8888
# Epoch 16/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2106 - accuracy: 0.9220 - val_loss: 0.3257 - val_accuracy: 0.8884
# Epoch 17/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.2073 - accuracy: 0.9226 - val_loss: 0.3347 - val_accuracy: 0.8866
# Epoch 18/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.1995 - accuracy: 0.9252 - val_loss: 0.3282 - val_accuracy: 0.8906
# Epoch 19/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1928 - accuracy: 0.9286 - val_loss: 0.3423 - val_accuracy: 0.8891
# Epoch 20/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1873 - accuracy: 0.9299 - val_loss: 0.3624 - val_accuracy: 0.8853
# Epoch 21/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1841 - accuracy: 0.9305 - val_loss: 0.3569 - val_accuracy: 0.8888
# Epoch 22/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1807 - accuracy: 0.9320 - val_loss: 0.3393 - val_accuracy: 0.8906
# Epoch 23/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1761 - accuracy: 0.9339 - val_loss: 0.3411 - val_accuracy: 0.8948
# Epoch 24/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1707 - accuracy: 0.9372 - val_loss: 0.3558 - val_accuracy: 0.8871
# Epoch 25/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1682 - accuracy: 0.9367 - val_loss: 0.3674 - val_accuracy: 0.8864
# Epoch 26/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1638 - accuracy: 0.9386 - val_loss: 0.3852 - val_accuracy: 0.8857
# Epoch 27/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1566 - accuracy: 0.9407 - val_loss: 0.3693 - val_accuracy: 0.8896
# Epoch 28/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1564 - accuracy: 0.9411 - val_loss: 0.3781 - val_accuracy: 0.8868
# Epoch 29/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1524 - accuracy: 0.9430 - val_loss: 0.3726 - val_accuracy: 0.8887
# Epoch 30/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1496 - accuracy: 0.9438 - val_loss: 0.4185 - val_accuracy: 0.8799

# %%
model.evaluate(x_test, t_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4277 - accuracy: 0.8810
# [0.4277305603027344, 0.8809999823570251]

# %%
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()

plt.plot(hist.history['loss'], label='train loss')
plt.plot(hist.history['val_loss'], label='validation loss')

plt.legend(loc='best')

plt.show()

# %%
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()

plt.plot(hist.history['accuracy'], label='train accuracy')
plt.plot(hist.history['val_accuracy'], label='validation accuracy')

plt.legend(loc='best')

plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(6, 6))

predicted_value = model.predict(x_test)

cm = confusion_matrix(t_test, 
                      np.argmax(predicted_value, axis=-1))

sns.heatmap(cm, annot=True, fmt='d')
plt.show()

# %%
print(cm)
print('\n')

for i in range(10):
    print(('label = %d\t(%d/%d)\taccuracy = %.3f') % 
          (i, np.max(cm[i]), np.sum(cm[i]), 
           np.max(cm[i])/np.sum(cm[i])))
# Out:
# [[819   3  20  19   5   0 127   0   6   1]
#  [  1 979   0  12   3   0   4   0   1   0]
#  [ 24   2 797  12  71   0  94   0   0   0]
#  [ 23   8  11 888  38   0  29   0   3   0]
#  [  1   1  94  30 785   0  89   0   0   0]
#  [  0   0   0   0   0 961   0  17   2  20]
#  [102   1  69  32  56   1 734   0   5   0]
#  [  0   0   0   0   0  10   0 919   2  69]
#  [ 11   1   5   4   3   3  18   4 951   0]
#  [  0   0   0   0   0   6   1  16   0 977]]
#
#
# label = 0	(819/1000)	accuracy = 0.819
# label = 1	(979/1000)	accuracy = 0.979
# label = 2	(797/1000)	accuracy = 0.797
# label = 3	(888/1000)	accuracy = 0.888
# label = 4	(785/1000)	accuracy = 0.785
# label = 5	(961/1000)	accuracy = 0.961
# label = 6	(734/1000)	accuracy = 0.734
# label = 7	(919/1000)	accuracy = 0.919
# label = 8	(951/1000)	accuracy = 0.951
# label = 9	(977/1000)	accuracy = 0.977

# %%
# 정답 및 예측 값 분포 확인
label_distribution = np.zeros(10)
prediction_distribution = np.zeros(10)

print(predicted_value.shape)
for idx in range(len(t_test)):

    label = int(t_test[idx])

    label_distribution[label] = label_distribution[label] + 1

    prediction = int(np.argmax(predicted_value[idx]))

    prediction_distribution[prediction] = prediction_distribution[prediction] + 1


print(label_distribution)
print(prediction_distribution)
# Out:
# (10000, 10)
# [1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000.]
# [ 981.  995.  996.  997.  961.  981. 1096.  956.  970. 1067.]
