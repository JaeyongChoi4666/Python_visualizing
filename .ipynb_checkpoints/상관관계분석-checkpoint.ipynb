# %% [markdown]
# # 데이터 상관관계 분석

# %% [markdown]
# # 상관분석과 상관계수
# - 우리는 일상생활에서 “키가 크면 발이 크다”, “교육수준이 높을수록 자녀의 대학 진학률이 높다”등의 이야기를 많이 한다.
# - 이러한 두 개의 변수 ‘키’와 ‘발’, ‘교육수준’과 ‘자녀 대학 진학률’간의 관계가 어떠한 관계를 가지고 있는지 성향을 분석하는 것이 “상관분석”이다.
# - 이를 ‘산포도’ 또는 ‘산점도’라는 그래프로 그리면 직관적으로 두 변수간의 관계를 파악할 수 있다.
# - 예) 어느 집단의 키와 발크기
# ![image.png](attachment:image.png)

# %% [markdown]
# # 산포도 그래프 작성(키와 발크기)

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib
font_location = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 220, 230, 250, 270, 280, 285]
plt.scatter(height, foot_size)
plt.xlabel('키(Cm)')
plt.ylabel('발크기(mm)')
plt.show()

# %% [markdown]
# # 산포도 그래프 작성(산의 높이에 따른 기온 변화)
# ![image.png](attachment:image.png)

# %%
h = [100, 200, 300, 400, 500, 600, 700, 800, 900]
t = [18.0, 17.5, 17, 16.5, 15, 14.5, 13, 12, 11]
plt.scatter(h, t)
plt.xlabel('산의높이(m)')
plt.ylabel('온도(℃)')
plt.show()

# %% [markdown]
# # 산포도 그래프 작성(상관관계가 없는 데이터)

# %%
random_x = np.random.randint(0, 100, 50)
random_y = np.random.randint(0, 100, 50)
plt.scatter(random_x, random_y)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.DataFrame({'height':height,'foot_size':foot_size})
#df=pd.DataFrame([height, foot_size]).T
sns.relplot(x='height',y='foot_size',data=df)

# %%
df=pd.DataFrame({'h':h,'t':t})
sns.relplot(x='h',y='t',data=df)

# %%
df=pd.DataFrame({'x':random_x, 'y':random_y})
sns.relplot(x='x',y='y',data=df)

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='time')

# %% [markdown]
# # 상관분석과 상관계수

# %% [markdown]
# - 상관계수
#     - 상관분석에서는 x의 값이 증가함에 따라 y의 값이 증가하는 경우 우리는 “양의 상관관계”를 가지고 있다.
#     - 상관 계수는 서로간의 데이터가 어느 정도의 근접도를 가지고 있는지 표현하는 방법
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 상관계수(기호 : r)
#  - -1≤r≤1 의 값을 가짐
# ![image.png](attachment:image.png)

# %% [markdown]
# - 상관관계 분석식(모집단 전체의 상관계수 공식)
# - 참조사이트: https://math100.tistory.com/111
# ![image.png](attachment:image.png)

# %% [markdown]
# - 상관관계 분석식(표본: 일부 샘플들의 상관계수 공식)
# ![image.png](attachment:image.png)

# %%
import math

def correlation(x, y):
    n = len(x)
    vals = range(n)
    x_sum = 0.0
    y_sum = 0.0
    x_sum_pow = 0.0
    y_sum_pow = 0.0
    mul_xy_sum = 0.0
    
    for i in vals:
        mul_xy_sum = mul_xy_sum + float(x[i]) * float(y[i])
        x_sum = x_sum + float(x[i])
        y_sum = y_sum + float(y[i])
        x_sum_pow = x_sum_pow + pow(float(x[i]), 2)
        y_sum_pow = y_sum_pow + pow(float(y[i]), 2)    
    try:
        r = ((n * mul_xy_sum) - (x_sum * y_sum)) /math.sqrt(((n*x_sum_pow)-pow(x_sum, 2))*((n*y_sum_pow) - pow(y_sum, 2)))
    except :
        print("error")
        r = 0.0
    return r

# %%
h = [100, 200, 300, 400, 500, 600, 700, 800, 900]
t = [18.0, 17.5, 17, 16.5, 15, 14.5, 13, 12, 11]
print(h)
print(t)
print('상관분석:',correlation(h, t))
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900]
# [18.0, 17.5, 17, 16.5, 15, 14.5, 13, 12, 11]
# 상관분석: -0.9879199164035135

# %%
df=pd.DataFrame({'h':h,'t':t})
#df=pd.DataFrame([h,t]).T
print(df.h.corr(df.t))
# Out:
# -0.9879199164035133

# %%
print(random_x)
print(random_y)
print('상관분석:',correlation(random_x, random_y))
# Out:
# [19 14 11 58 69 28 14 39 74  9 18 63 14 10 54 48 58 29 95 40 64  7  4 11
#  98 51 13 75 76 61 26 99 84 84 70  9 80  3 16 60 62 12 82 26  3 42 18 67
#  88 63]
# [68 73 12 53 74 49 14 21 61 64 75 10 46 14 43 41 85 76 63  5 96 40 79 39
#   9 98 91 67 89 51 51 61 72 38  8 87  2 24 88 63 54 15 60  4 70 34 67 60
#  53 74]
# 상관분석: 0.019233528112209422

# %%
df=pd.DataFrame({'x':random_x, 'y':random_y})
print(df.x.corr(df.y))
# Out:
# 0.019233528112209446

# %% [markdown]
# # Pandas 사용 상관관계분석

# %%
df=pd.DataFrame({'h':h,'t':t})
print(df.h.corr(df.t))
# Out:
# -0.9879199164035133

# %%
df=pd.DataFrame({'x':random_x, 'y':random_y})
print(df.x.corr(df.y))
# Out:
# -0.04120935746294202

# %%
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 220, 230, 250, 270, 280, 285]
list=[height, foot_size]
df=pd.DataFrame(list).T
print(df)
corr=df.corr(method='pearson')
print(corr)
# Out:
#      0    1
# 0  100  200
# 1  120  205
# 2  130  210
# 3  140  220
# 4  150  230
# 5  160  250
# 6  170  270
# 7  180  280
# 8  190  285
#           0         1
# 0  1.000000  0.966126
# 1  0.966126  1.000000

# %%
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 220, 230, 250, 270, 280, 285]
weight=[25, 30, 38, 35, 40, 45, 55, 68, 70]
list=[height, foot_size,weight]
df=pd.DataFrame(list).T
print(df)
corr=df.corr(method='pearson')
print(corr)
# Out:
#      0    1   2
# 0  100  200  25
# 1  120  205  30
# 2  130  210  38
# 3  140  220  35
# 4  150  230  40
# 5  160  250  45
# 6  170  270  55
# 7  180  280  68
# 8  190  285  70
#           0         1         2
# 0  1.000000  0.966126  0.952271
# 1  0.966126  1.000000  0.969807
# 2  0.952271  0.969807  1.000000

# %%
tips.corr(method='pearson')
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# # 상관관계 시각화-heatmap

# %%
df_heatmap = sns.heatmap(corr,  #상관계수 값
                         cbar=True,  #사이드바 표시
                         annot=True,  # 실제값 화면에 표시여부
                         annot_kws={'size': 15},  #글자 크기
                         fmt='.3f',   #소수점 자리수 지징
                         square=True, # 정사각형으로 표시 여부
                         cmap='Blues')  #색장지정, Reds, Greens, Blues

# %%
df_heatmap = sns.heatmap(corr, 
                         cbar=True, 
                         annot=True, 
                         annot_kws={'size': 20}, 
                         cmap='RdYlBu_r', #red, yellow, blue 생상으로 표시
                         vmin=0.95,vmax=1) # 색상 표시 최대값과 최소값

# %%
tips_corr=tips.corr(method='pearson')
print(tips_corr)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df_heatmap = sns.heatmap(tips_corr, 
                         cbar=True, 
                         annot=True, 
                         annot_kws={'size': 20}, 
                         cmap='RdYlBu_r', #red, yellow, blue 생상으로 표시
                         vmin=0.4,vmax=1) # 색상 표시 최대값과 최소값

# %%
df_heatmap = sns.heatmap(corr, 
                         cbar=True, 
                         annot=True, 
                         annot_kws={'size': 20}, 
                         cmap='RdYlBu_r', #red, yellow, blue 생상으로 표시
                         vmin=0.95,vmax=1) # 색상 표시 최대값과 최소값

# %%
import numpy as np
fig, ax=plt.subplots(figsize=(7,7))
mask=np.zeros_like(corr) # 삼각형 마스크 만들기 위쪽 삼각형에 False
#mask=np.zeros_like(corr, dtype=np.bool) # 삼각형 마스크 만들기 위쪽 삼각형에 False
mask[np.triu_indices_from(mask)]=True #아래쪽 삼각형에 True
df_heatmap = sns.heatmap(
    corr, 
    cbar_kws={'shrink':.8}, # 컬라바 크기 절반으로 줄이기
    annot=True, 
    mask=mask, #표시하지 않는 마스크 부분 지정
    linewidth=.5, # 경계면 시선으로 구분하기
    cmap='RdYlBu_r', #red, yellow, blue 색상으로 표시
    vmin=0.95,vmax=0.97)

# %%
normal_data = np.random.randn(10, 12)
ax = sns.heatmap(normal_data, center=0)
