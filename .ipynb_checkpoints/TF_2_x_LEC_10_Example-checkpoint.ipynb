# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist

(x_train, t_train), (x_test, t_test) = mnist.load_data()

print('\n train shape = ', x_train.shape, 
      ', train label shape = ', t_train.shape)
print(' test shape = ', x_test.shape, 
      ', test label shape =', t_test.shape)

print('\n train label = ', t_train)  # 학습데이터 정답 출력
print(' test label  = ', t_test)     # 테스트 데이터 정답 출력
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
#
#  train shape =  (60000, 28, 28) , train label shape =  (60000,)
#  test shape =  (10000, 28, 28) , test label shape = (10000,)
#
#  train label =  [5 0 4 ... 5 6 8]
#  test label  =  [7 2 1 ... 4 5 6]

# %%
import matplotlib.pyplot as plt

# 25개의 이미지 출력
plt.figure(figsize=(6, 6)) 

for index in range(25):    # 25 개 이미지 출력

    plt.subplot(5, 5, index + 1)  # 5행 5열 
    plt.imshow(x_train[index], cmap='gray') 
    plt.axis('off')   
    # plt.title(str(t_train[index]))

plt.show()

# %%
plt.imshow(x_train[9], cmap='gray') 
plt.colorbar()   
plt.show()

# %%
plt.title('train label distribution')
plt.grid()
plt.xlabel('label')

plt.hist(t_train, bins=10, rwidth=0.8)

plt.show()

# %%
# 학습데이터 정답 분포 확인

label_distribution = np.zeros(10)

for idx in range(len(t_train)):

    label = int(t_train[idx])

    label_distribution[label] = label_distribution[label] + 1


print(label_distribution)
# Out:
# [5923. 6742. 5958. 6131. 5842. 5421. 5918. 6265. 5851. 5949.]

# %%
# 학습 데이터 / 테스트 데이터 정규화 (Normalization)

x_train = (x_train - 0.0) / (255.0 - 0.0)

x_test = (x_test - 0.0) / (255.0 - 0.0)


# 정답 데이터 원핫 인코딩 (One-Hot Encoding)

t_train = tf.keras.utils.to_categorical(t_train, num_classes=10)

t_test = tf.keras.utils.to_categorical(t_test, num_classes=10)

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))

model.add(tf.keras.layers.Dense(100, activation='relu'))

model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               78500
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train, t_train, epochs=30, validation_split=0.3)
# Out:
# Epoch 1/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.3166 - accuracy: 0.9095 - val_loss: 0.1824 - val_accuracy: 0.9477
# Epoch 2/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1455 - accuracy: 0.9566 - val_loss: 0.1366 - val_accuracy: 0.9599
# Epoch 3/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.1002 - accuracy: 0.9703 - val_loss: 0.1236 - val_accuracy: 0.9625
# Epoch 4/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0757 - accuracy: 0.9771 - val_loss: 0.1106 - val_accuracy: 0.9674
# Epoch 5/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0578 - accuracy: 0.9828 - val_loss: 0.1172 - val_accuracy: 0.9642
# Epoch 6/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0459 - accuracy: 0.9862 - val_loss: 0.1078 - val_accuracy: 0.9682
# Epoch 7/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0376 - accuracy: 0.9885 - val_loss: 0.1123 - val_accuracy: 0.9682
# Epoch 8/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0303 - accuracy: 0.9910 - val_loss: 0.1045 - val_accuracy: 0.9713
# Epoch 9/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0236 - accuracy: 0.9936 - val_loss: 0.1002 - val_accuracy: 0.9710
# Epoch 10/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0207 - accuracy: 0.9940 - val_loss: 0.1053 - val_accuracy: 0.9720
# Epoch 11/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.1050 - val_accuracy: 0.9721
# Epoch 12/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.1076 - val_accuracy: 0.9728
# Epoch 13/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 0.1154 - val_accuracy: 0.9709
# Epoch 14/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.1219 - val_accuracy: 0.9716
# Epoch 15/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.1191 - val_accuracy: 0.9715
# Epoch 16/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.1357 - val_accuracy: 0.9719
# Epoch 17/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.1246 - val_accuracy: 0.9721
# Epoch 18/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.1324 - val_accuracy: 0.9709
# Epoch 19/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.1283 - val_accuracy: 0.9726
# Epoch 20/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.1286 - val_accuracy: 0.9737
# Epoch 21/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.1361 - val_accuracy: 0.9723
# Epoch 22/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.1480 - val_accuracy: 0.9707
# Epoch 23/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.1368 - val_accuracy: 0.9738
# Epoch 24/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.1505 - val_accuracy: 0.9731
# Epoch 25/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.1721 - val_accuracy: 0.9686
# Epoch 26/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.1532 - val_accuracy: 0.9724
# Epoch 27/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1412 - val_accuracy: 0.9747
# Epoch 28/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.1498 - val_accuracy: 0.9730
# Epoch 29/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1602 - val_accuracy: 0.9713
# Epoch 30/30
# 1313/1313 [==============================] - 2s 1ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.1495 - val_accuracy: 0.9752

# %%
model.evaluate(x_test, t_test)
# Out:
# 313/313 [==============================] - 0s 885us/step - loss: 0.1201 - accuracy: 0.9783
# [0.12013202160596848, 0.9782999753952026]

# %%
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()

plt.plot(hist.history['loss'], label='train loss')
plt.plot(hist.history['val_loss'], label='validation loss')

plt.legend(loc='best')

plt.show()

# %%
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()

plt.plot(hist.history['accuracy'], label='train accuracy')
plt.plot(hist.history['val_accuracy'], label='validation accuracy')

plt.legend(loc='best')

plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(6, 6))

predicted_value = model.predict(x_test)

cm = confusion_matrix(np.argmax(t_test, axis=-1),
                      np.argmax(predicted_value, axis=-1))

sns.heatmap(cm, annot=True, fmt='d')
plt.show()

# %%
print(cm)
print('\n')

for i in range(10):
    print(('label = %d\t(%d/%d)\taccuracy = %.3f') % 
          (i, np.max(cm[i]), np.sum(cm[i]), 
           np.max(cm[i])/np.sum(cm[i])))
# Out:
# [[ 971    0    1    0    1    0    4    2    1    0]
#  [   0 1124    2    1    0    0    2    1    5    0]
#  [   4    1 1012    1    1    0    3    5    5    0]
#  [   0    0    6  988    0    7    0    3    2    4]
#  [   1    1    3    1  957    1    2    1    2   13]
#  [   2    1    0   10    1  861    7    2    4    4]
#  [   2    2    1    1    3    3  944    0    2    0]
#  [   1    2    7    4    1    1    0 1000    2   10]
#  [   5    0    2    2    5    2    3    4  947    4]
#  [   2    3    0    6   10    4    0    3    2  979]]
#
#
# label = 0	(971/980)	accuracy = 0.991
# label = 1	(1124/1135)	accuracy = 0.990
# label = 2	(1012/1032)	accuracy = 0.981
# label = 3	(988/1010)	accuracy = 0.978
# label = 4	(957/982)	accuracy = 0.975
# label = 5	(861/892)	accuracy = 0.965
# label = 6	(944/958)	accuracy = 0.985
# label = 7	(1000/1028)	accuracy = 0.973
# label = 8	(947/974)	accuracy = 0.972
# label = 9	(979/1009)	accuracy = 0.970

# %%
# 정답 및 예측 값 분포 확인
label_distribution = np.zeros(10)
prediction_distribution = np.zeros(10)

for idx in range(len(t_test)):

    label = int(np.argmax(t_test[idx]))

    label_distribution[label] = label_distribution[label] + 1

    prediction = int(np.argmax(predicted_value[idx]))

    prediction_distribution[prediction] = prediction_distribution[prediction] + 1


print(label_distribution)
print(prediction_distribution)
# Out:
# [ 980. 1135. 1032. 1010.  982.  892.  958. 1028.  974. 1009.]
# [ 988. 1134. 1034. 1014.  979.  879.  965. 1021.  972. 1014.]
